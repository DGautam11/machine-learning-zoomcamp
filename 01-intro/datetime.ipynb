# %%
import datetime

# %%
d = datetime.date(2026,7,24)
print(d)
# Out:
# 2026-07-24

# %%
today = datetime.date.today()
print(today)
print(today.year)
print(today.day)
print(today.weekday())
print(today.isoweekday())
# Out:
# 2026-08-21
# 2026
# 21
# 4
# 5

# %%
tdelta = datetime.timedelta(days=7)

# %%
print(today + tdelta)
# Out:
# 2026-08-28

# %%
print(today - tdelta)
# Out:
# 2026-08-14

# %%
bday = datetime.date(2026,9,24)

# %%
till_bday = bday - today
print(till_bday)
print(till_bday.days)
# Out:
# 34 days, 0:00:00
# 34

# %%
t = datetime.time(8,54,45,10000)
print(t)
print(t.hour)
# Out:
# 08:54:45.010000
# 8

# %%
dt = datetime.datetime(2026,7,26,12,20,30,100000)
print(dt)
# Out:
# 2026-07-26 12:20:30.100000

# %%
print(dt.date())
print(dt.time())
print(dt.year)
# Out:
# 2026-07-26
# 12:20:30.100000
# 2026

# %%
tdelta = datetime.timedelta(days=7)

# %%
print(dt + tdelta)
# Out:
# 2026-08-02 12:20:30.100000

# %%
tdelta = datetime.timedelta(hours=10)
print(dt+ tdelta)
# Out:
# 2026-07-26 22:20:30.100000

# %%
dt_today = datetime.datetime.today()
dt_now = datetime.datetime.now()
dt_utcnow = datetime.datetime.now(datetime.UTC)

# %%
print(dt_today)
print(dt_now)
print(dt_utcnow)
# Out:
# 2026-08-21 05:59:59.739359
# 2026-08-21 05:59:59.739407
# 2026-08-21 05:59:59.739444+00:00
