# %%
class Employee:

    raise_amount = 1.04
    num_of_emps = 0

    def __init__(self,first,last,pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@company.com'
        
        Employee.num_of_emps += 1

    def fullname(self):
        return '{} {}'.format(self.first,self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amount)

    @classmethod
    def set_raise_amt(cls, amount):
        cls.raise_amount = amount

    @classmethod
    def from_string(cls,emp_str):
        first, last, pay = emp_str.split('-')
        return cls(first, last, pay)

    @staticmethod
    def is_workday(day):
        if day.weekday() == 5 or day.weekday() == 6:
            return False
        return True

# %%
emp_1 = Employee('Corey','Schfer',60000)
emp_2 = Employee('Test','User',70000)

print(emp_1)
print(emp_2)
# Out:
# <__main__.Employee object at 0x799c42bfb500>
# <__main__.Employee object at 0x799c30c16ed0>

# %%
print(emp_1.__dict__)
print(Employee.__dict__)
# Out:
# {'first': 'Corey', 'last': 'Schfer', 'pay': 60000, 'email': 'Corey.Schfer@company.com'}
# {'__module__': '__main__', 'raise_amount': 1.04, '__init__': <function Employee.__init__ at 0x723564695bc0>, 'fullname': <function Employee.fullname at 0x723564697100>, 'apply_raise': <function Employee.apply_raise at 0x723564694540>, '__dict__': <attribute '__dict__' of 'Employee' objects>, '__weakref__': <attribute '__weakref__' of 'Employee' objects>, '__doc__': None}

# %%
Employee.set_raise_amt(1.05)
print("---------------")
print(emp_1.raise_amount)
print(Employee.raise_amount)
print(emp_2.raise_amount)
# Out:
# ---------------
# 1.05
# 1.05
# 1.05

# %%
print(emp_1.fullname())
# Out:
# Corey Schfer

# %%
print(Employee.num_of_emps)
# Out:
# 2

# %%
emp_str_1 = 'John-Doe-70000'
emp_str_2 = 'Steve-Smith-30000'
emp_str_3 = 'Jane-Doe-90000'

# %%
new_emp_1 = Employee.from_string(emp_str_1)

# %%
print(new_emp_1.first)
# Out:
# John

# %%
import datetime
my_date =  datetime.date(2016,7,12)

print(Employee.is_workday(my_date))
# Out:
# True

# %%
class Developer(Employee):
    raise_amount = 1.10

    def __init__(self, first, last, pay, prog_lang):
        super().__init__(first, last, pay) #These argument is handled by parent init method
        self.prog_lang = prog_lang

# %%
dev_1 = Developer('Corey','Schafer',50000,'Python')
dev_2 = Developer('Test','Employee',60000,'Java')

# %%
print(dev_1.email)
print(dev_1.prog_lang)
print(dev_2.email)
# Out:
# Corey.Schafer@company.com
# Python
# Test.Employee@company.com

# %%
#print(help(Developer))
print(dev_1.pay)
dev_1.apply_raise()
print(dev_1.pay)
# Out:
# 52000
# 54080

# %%
class Manager(Employee):
    
    def __init__(self, first, last, pay, employees=None):
        super().__init__(first, last, pay)
        if employees is None:
            self.employees = []
        else:
            self.employees = employees

    def add_emp(self,emp):
        if emp not in self.employees:
            self.employees.append(emp)

    def remove_emp(self,emp):
        if emp in self.employees:
            self.employees.remove(emp)

    def print_emps(self):
        for emp in self.employees:
            print('--L',emp.fullname())

# %%
mgr_1 = Manager('Sue','Smith',90000, [dev_1])

# %%
print(mgr_1.email)
# Out:
# Sue.Smith@company.com

# %%
mgr_1.print_emps()
# Out:
# --L Corey Schafer
# --L Test Employee

# %%
mgr_1.add_emp(dev_2)

# %%
mgr_1.remove_emp(dev_1)

# %%
mgr_1.print_emps()
# Out:
# --L Test Employee

# %%
print(isinstance(mgr_1, Manager))
print(isinstance(mgr_1, Employee))
print(isinstance(mgr_1, Developer))
# Out:
# True
# True
# False

# %%
print(issubclass(Developer, Employee))
print(issubclass(Manager,Employee))
print(issubclass(Manager,Developer))
# Out:
# True
# True
# False
