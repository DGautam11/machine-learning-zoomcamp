# %%
import os

# %%
print(dir(os))
# Out:
# ['CLD_CONTINUED', 'CLD_DUMPED', 'CLD_EXITED', 'CLD_KILLED', 'CLD_STOPPED', 'CLD_TRAPPED', 'CLONE_FILES', 'CLONE_FS', 'CLONE_NEWCGROUP', 'CLONE_NEWIPC', 'CLONE_NEWNET', 'CLONE_NEWNS', 'CLONE_NEWPID', 'CLONE_NEWTIME', 'CLONE_NEWUSER', 'CLONE_NEWUTS', 'CLONE_SIGHAND', 'CLONE_SYSVSEM', 'CLONE_THREAD', 'CLONE_VM', 'DirEntry', 'EFD_CLOEXEC', 'EFD_NONBLOCK', 'EFD_SEMAPHORE', 'EX_CANTCREAT', 'EX_CONFIG', 'EX_DATAERR', 'EX_IOERR', 'EX_NOHOST', 'EX_NOINPUT', 'EX_NOPERM', 'EX_NOUSER', 'EX_OK', 'EX_OSERR', 'EX_OSFILE', 'EX_PROTOCOL', 'EX_SOFTWARE', 'EX_TEMPFAIL', 'EX_UNAVAILABLE', 'EX_USAGE', 'F_LOCK', 'F_OK', 'F_TEST', 'F_TLOCK', 'F_ULOCK', 'GRND_NONBLOCK', 'GRND_RANDOM', 'GenericAlias', 'MFD_ALLOW_SEALING', 'MFD_CLOEXEC', 'MFD_HUGETLB', 'MFD_HUGE_16GB', 'MFD_HUGE_16MB', 'MFD_HUGE_1GB', 'MFD_HUGE_1MB', 'MFD_HUGE_256MB', 'MFD_HUGE_2GB', 'MFD_HUGE_2MB', 'MFD_HUGE_32MB', 'MFD_HUGE_512KB', 'MFD_HUGE_512MB', 'MFD_HUGE_64KB', 'MFD_HUGE_8MB', 'MFD_HUGE_MASK', 'MFD_HUGE_SHIFT', 'Mapping', 'MutableMappi
# ...

# %%
print(os.getcwd())
# Out:
# /workspaces/machine-learning-zoomcamp/01-intro

# %%
os.chdir('/workspaces/')

# %%
print(os.getcwd())
# Out:
# /workspaces

# %%
print(os.listdir())
# Out:
# ['.codespaces', 'machine-learning-zoomcamp', '.oryx']

# %%
#os.makdir('OS-DEMO')
#DIRS MAKE LEADING FOLDER AS WELL
os.makedirs('OS-DEMO/SUB-DIR')

# %%
os.rmdir('OS-DEMO')
##ALSO DELETE LEADING FOLDERS
os.removedirs('OS-DEMO/SUB-DIR')

# %%
print(os.getcwd())
os.chdir('machine-learning-zoomcamp')
# Out:
# /workspaces/machine-learning-zoomcamp
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 2
#       1 print(os.getcwd())
# ----> 2 os.chdir('machine-learning-zoomcamp')
#       4 print(os.listdir())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'machine-learning-zoomcamp'

# %%
print(os.listdir())
# Out:
# ['.gitignore', '01-intro', '.ipynb_checkpoints', 'README.md', '.git']

# %%
os.chdir('01-intro')

# %%
os.rename('text.txt','demo.txt')

# %%
print(os.stat('demo.txt'))
# Out:
# os.stat_result(st_mode=33206, st_ino=1324601, st_dev=1796, st_nlink=1, st_uid=1000, st_gid=1000, st_size=0, st_atime=1787137695, st_mtime=1787137695, st_ctime=1787137872)

# %%
print(os.stat('demo.txt').st_mtime)
# Out:
# 1787137695.2651732

# %%
from datetime import datetime
print(datetime.fromtimestamp(os.stat('demo.txt').st_mtime))
# Out:
# 2026-08-19 11:08:15.265173

# %%
os.chdir('/workspaces')

# %%
for dirpath,dirname,filenames in os.walk(os.getcwd()):
    print('Current Path:',dirpath)
    print('Directories:',dirname)
    print('Files:',filenames)
    print()
# Out:
# Current Path: /workspaces
# Directories: ['OS-DEMO', '.codespaces', 'machine-learning-zoomcamp', '.oryx']
# Files: []
#
# Current Path: /workspaces/OS-DEMO
# Directories: ['SUB-DIR']
# Files: []
#
# Current Path: /workspaces/OS-DEMO/SUB-DIR
# Directories: []
# Files: []
#
# Current Path: /workspaces/.codespaces
# Directories: ['shared', '.persistedshare']
# Files: []
#
# Current Path: /workspaces/.codespaces/shared
# Directories: []
# Files: ['.env', '.environmentConfigurationCompleted', '.user-secrets.json', 'environment-variables.json', 'cs-agent.sock', 'postCreateOutput.json', 'user-secrets-envs.json', 'devContainerTelemetry.json', '.env-secrets', 'codespaceStatusTool.js', 'resource-usage.json', 'merged_devcontainer.json', 'read-config.json']
#
# Current Path: /workspaces/.codespaces/.persistedshare
# Directories: ['devcontainers-cli', '.docker']
# ...

# %%
print(os.environ.get('HOME'))
# Out:
# /home/codespace

# %%
file_path = os.path.join(os.environ.get('HOME'),'test.txt')
print(file_path)
# Out:
# /home/codespace/test.txt

# %%
print(os.path.basename('/tmp/test.txt'))
print(os.path.dirname('/tmp/test.txt'))
print(os.path.split('/tmp/test.txt'))
# Out:
# test.txt
# /tmp
# ('/tmp', 'test.txt')

# %%
print(os.path.exists('/tmp/test.txt'))
print(os.path.isdir('/tmp/test.txt'))
print(os.path.isfile('/tmp/test.txt'))
# Out:
# False
# False
# False

# %%
print(os.path.splitext('/tmp/test.txt'))
# Out:
# ('/tmp/test', '.txt')

# %%
print(dir(os.path))
# Out:
# ['__all__', '__builtins__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_get_sep', '_joinrealpath', '_path_normpath', '_varprog', '_varprogb', 'abspath', 'altsep', 'basename', 'commonpath', 'commonprefix', 'curdir', 'defpath', 'devnull', 'dirname', 'exists', 'expanduser', 'expandvars', 'extsep', 'genericpath', 'getatime', 'getctime', 'getmtime', 'getsize', 'isabs', 'isdir', 'isfile', 'isjunction', 'islink', 'ismount', 'join', 'lexists', 'normcase', 'normpath', 'os', 'pardir', 'pathsep', 'realpath', 'relpath', 'samefile', 'sameopenfile', 'samestat', 'sep', 'split', 'splitdrive', 'splitext', 'splitroot', 'stat', 'supports_unicode_filenames', 'sys']
